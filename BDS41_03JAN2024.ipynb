# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreaj11/TakeoBDS41/blob/main/BDS41_03JAN2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# New Year 2024
#
# # **Python Pandas**

# %%
import pandas as pd
import numpy as np
path = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle = pd.read_csv(path,sep = '\t')
df_chipotle

# %%
df_chipotle.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df_chipotle.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
df_chipotle.shape
# Out:
# (4622, 5)

# %%
df_chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df_chipotle.size
# Out:
# 23110

# %%
df_chipotle.describe
# Out:
# <bound method NDFrame.describe of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df_chipotle.describe(include = 'all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
df_chipotle.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df_chipotle.notna()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0         True      True       True               False        True
# 1         True      True       True                True        True
# 2         True      True       True                True        True
# 3         True      True       True               False        True
# 4         True      True       True                True        True
# ...        ...       ...        ...                 ...         ...
# 4617      True      True       True                True        True
# 4618      True      True       True                True        True
# 4619      True      True       True                True        True
# 4620      True      True       True                True        True
# 4621      True      True       True                True        True
#
# [4622 rows x 5 columns]

# %%
df_chipotle.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df_chipotle.item_name.value_counts().sum()

# %%
df_chipotle.item_name.value_counts().head()

# %%
df_chipotle.item_name.value_counts().max()

# %%
df_chipotle.item_name.value_counts().min()

# %% [markdown]
# # **Filter and Sorting**

# %%
dollarizer = lambda x: float(x[1: -1])
df_chipotle.item_price = df_chipotle.item_price.apply(dollarizer)
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipotle[df_chipotle.item_price > 10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
df_chipotle[(df_chipotle.item_price > 10) & (df_chipotle.item_name == 'Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# 123         54         1  Chicken Bowl
# ...        ...       ...           ...
# 4576      1820         1  Chicken Bowl
# 4586      1824         1  Chicken Bowl
# 4587      1824         1  Chicken Bowl
# 4589      1825         1  Chicken Bowl
# 4590      1825         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# 123   [Fresh Tomato Salsa, [Guacamole, Cheese, Sour ...       11.25
# ...                                                 ...         ...
# ...

# %%
df_chipotle[(df_chipotle.item_price < 10) & (df_chipotle.item_name =='Veggie Bowl')]
# Out:
#       order_id  quantity    item_name  \
# 85          38         1  Veggie Bowl
# 164         74         1  Veggie Bowl
# 253        110         1  Veggie Bowl
# 287        125         1  Veggie Bowl
# 512        215         1  Veggie Bowl
# 515        215         1  Veggie Bowl
# 619        255         1  Veggie Bowl
# 643        266         1  Veggie Bowl
# 677        280         1  Veggie Bowl
# 843        346         1  Veggie Bowl
# 887        367         1  Veggie Bowl
# 936        386         1  Veggie Bowl
# 1319       537         1  Veggie Bowl
# 1433       580         1  Veggie Bowl
# 1441       585         1  Veggie Bowl
# 1454       590         1  Veggie Bowl
# 1644       664         1  Veggie Bowl
# 1749       706         1  Veggie Bowl
# 1833       742         1  Veggie Bowl
# 1841       746         1  Veggie Bowl
# 2028       817         1  Veggie Bowl
# 2034       818         1  Veggie Bowl
# 2039       820         1  Veggie Bowl
# ...

# %%
df_chipotle[df_chipotle.item_price > 10]
# Out:
#      order_id  quantity                     item_name  \
# 21         11         1              Barbacoa Burrito
# 22         11         1              Nantucket Nectar
# 23         12         1               Chicken Burrito
# 24         12         1                          Izze
# 25         13         1  Chips and Fresh Tomato Salsa
# ..        ...       ...                           ...
# 222        98         1              Barbacoa Burrito
# 223        98         2                         Chips
# 224        98         1                  Chicken Bowl
# 225        99         1                Veggie Burrito
# 226        99         1                         Chips
#
#                                     choice_description  item_price
# 21   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...        8.99
# 22                                [Pomegranate Cherry]        3.39
# 23   [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %% [markdown]
# # **Group By Functions**

# %%
import pandas as pd

users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = '|', index_col = 'user_id')

users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
users.groupby(['occupation','gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
users.groupby(['occupation', 'gender']).age.agg(['min', 'max', 'mean'])
# Out:
#                       min  max       mean
# occupation    gender
# administrator F        22   62  40.638889
#               M        21   70  37.162791
# artist        F        19   48  30.307692
#               M        20   45  32.333333
# doctor        M        28   64  43.571429
# educator      F        23   51  39.115385
#               M        25   63  43.101449
# engineer      F        23   36  29.500000
#               M        22   70  36.600000
# entertainment F        24   38  31.000000
#               M        15   50  29.000000
# executive     F        39   49  44.000000
#               M        22   69  38.172414
# healthcare    F        22   53  39.818182
#               M        28   62  45.400000
# homemaker     F        20   50  34.166667
#               M        23   23  23.000000
# lawyer        F        28   51  39.500000
#               M        21   53  36.200000
# librarian     F        26   59  40.000000
#               M        23   69  40.000000
# ...
