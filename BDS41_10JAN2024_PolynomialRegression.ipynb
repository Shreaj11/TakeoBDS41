# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreaj11/TakeoBDS41/blob/main/BDS41_10JAN2024_PolynomialRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/Position_Salaries 1.csv'
df = pd.read_csv(path)
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'green')
plt.plot(X, lin_reg.predict(X), color = 'red')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'green')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')

# %%
lin_reg.predict([[5.5]])
# Out:
# array([249500.])

# %%
lin_reg_2.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# array([132148.43750002])

# %% [markdown]
# # **Support Vector Regression(SVR)**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/Position_Salaries 1.csv'
df = pd.read_csv(path)
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %%
from sklearn.svm import SVR
regressor = SVR(kernel ='rbf')
regressor.fit(X,y)
# Out:
# SVR()

# %%
plt.scatter(X,y,color = 'grey')
plt.plot(X,y, color='blue')

# %%
regressor.predict([[5.5]])
# Out:
# array([130000.])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/Position_Salaries 1.csv'
df = pd.read_csv(path)
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y.reshape(-1,1))

# %%
X, y
# Out:
# (array([[-1.5666989 ],
#         [-1.21854359],
#         [-0.87038828],
#         [-0.52223297],
#         [-0.17407766],
#         [ 0.17407766],
#         [ 0.52223297],
#         [ 0.87038828],
#         [ 1.21854359],
#         [ 1.5666989 ]]),
#  array([[-0.72004253],
#         [-0.70243757],
#         [-0.66722767],
#         [-0.59680786],
#         [-0.49117815],
#         [-0.35033854],
#         [-0.17428902],
#         [ 0.17781001],
#         [ 0.88200808],
#         [ 2.64250325]]))

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
sc_y.inverse_transform(regressor.predict(sc_X.transform([[5.5]])).reshape(-1,1))
# Out:
# array([[252789.19575201]])

# %%
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(sc_X.inverse_transform(X), sc_y.inverse_transform(regressor.predict(X).reshape(-1,1)), color = 'blue')

# %% [markdown]
# # **Decision Tree**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/Position_Salaries 1.csv'
df = pd.read_csv(path)
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = df.iloc[:,1:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state= 0)
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
regressor.predict([[5.5]])
# Out:
# array([110000.])

# %%
X_grid = np.arange(min(X),max(X),0.01)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y,color='yellow')
plt.plot(X_grid,regressor.predict(X_grid), color='blue')

# %% [markdown]
# # **Random Forest Regression**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/Position_Salaries 1.csv'
df = pd.read_csv(path)
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = df.iloc[:,1:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators= 10, random_state= 0)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
regressor.predict([[5.5]])
# Out:
# array([108000.])

# %%
X_grid = np.arange(min(X),max(X),0.01)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y,color='red')
plt.plot(X_grid,regressor.predict(X_grid), color='blue')
